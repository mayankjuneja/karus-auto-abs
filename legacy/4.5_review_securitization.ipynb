# %% [markdown]
# ### Load libs

# %%
import pandas as pd

# %%
n = 750
pd.set_option('display.max_columns', n)
pd.set_option('display.max_rows', n)
pd.set_option('display.max_colwidth', -1)
# Out:
# /anaconda3/envs/kn/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   after removing the cwd from sys.path.

# %% [markdown]
# ### Load data

# %%
folder = 'data/static/prepared/combined/'
file = 'AmeriCredit securitizations.csv'
path = folder + file
data = pd.read_csv(path)

# %%
folder_2 = 'data/transaction/'
file_2 = 'AmeriCredit Automobile Receivables Trust 2017-1 Data Tape transaction prepared.csv'
path_2 = folder_2 + file_2
transaction = pd.read_csv(path_2)
# Out:
# /anaconda3/envs/kn/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (26) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### Get IDs

# %%
transaction['id'] = transaction['ID'] + ' 2017-1'
t_ids = list(transaction['id'].unique())

# %%
d_sub = data[data['id'].str.contains('2017-1')].reset_index(drop = True)
d_ids = list(d_sub['id'].unique())

# %%
len(d_ids)
# Out:
# 50671

# %%
data.head(1)
# Out:
#                            id  records  \
# 0  0001694010 - 000010-2017-1  27
#
#   reportingPeriodBeginningDateRLocCurrent  \
# 0  2020-12-01
#
#   reportingPeriodEndingDateRLocCurrent originationDateRLocCurrent  \
# 0  2020-12-31                           2012-03
#
#   loanMaturityDateRLocCurrent originalFirstPaymentDateRLocCurrent  \
# 0  2018-12                     2012-05
#
#   interestPaidThroughDateRLocCurrent zeroBalanceEffectiveDateRLocCurrent  \
# 0  NaN                                2017-07
#
#    mostRecentServicingTransferReceivedDateRLocCurrent  \
# 0 NaN
#
#    DemandResolutionDateRLocCurrent  \
# 0 NaN
#
#                                                      dataset_nameLocCurrent  \
# 0  2021.01.22_AmeriCredit Automobile Receivables Trust 2017-1 Data Tape.csv
#
#             assetTypeNumberLocCurrent originatorNameLocCurrent  \
# 0  CIK number-Sequential asset number  GM FINANCIAL
#
#    originalLoanAmountLocCurrent  originalLoanTermLocCurrent  \
# ...
