# %% [markdown]
# ### Load libs

# %%
import pandas as pd
import json
import numpy as np
import random
from pandarallel import pandarallel

pandarallel.initialize()
# Out:
# INFO: Pandarallel will run on 12 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
n = 500
pd.set_option('display.max_columns', n)
pd.set_option('display.max_rows', n)
pd.set_option('display.max_colwidth', -1)
# Out:
# /anaconda3/envs/kn/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   after removing the cwd from sys.path.

# %% [markdown]
# ### Load data

# %%
term = 'AmeriCredit Automobile Receivables Trust 2017-1 Data Tape'

# %%
# load abs
folder = 'data/combined/'
file = '{}.csv'.format(term)
path = folder + file
data = pd.read_csv(path)
data.shape
# Out:
# /anaconda3/envs/kn/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (38,39,57) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (1511394, 73)

# %%
# load mapper
m_folder = 'data/dictionary/mapper/'
m_file = 'mapper.json'
m_path = m_folder + m_file
with open(m_path) as f:
    mapper = json.load(f)
m_cols = list(mapper.keys())

# %%
s_folder = 'data/static/'
s_file = '{} static.csv'.format(term)
s_path = s_folder + s_file
s_path
# Out:
# 'data/static/AmeriCredit Automobile Receivables Trust 2017-1 Data Tape static.csv'

# %%
static = pd.read_csv(s_path)

# %% [markdown]
# ### Formatting

# %%
def convert_id(row, column):
    
    """
    Convert ids
    """
    
    init = str(row[column])
    
    cleaned = init.replace('=', '').replace('"', '').strip()
    
    return cleaned

# %%
def reorder_date(row, column):
    
    """
    Reorder date
    """
    
    init = str(row[column])
    if init != '-':
        if '/' not in init:
            y = init[6:10]
            m = init[0:2]
            d = init[3:5]
            date = y + '-' + m + '-' + d
        elif '/' in init:
            y = init[3:7]
            m = init[0:2]
            date = y + '-' + m
    else:
        date = ''
    
    return date

# %%
data['ID'] = data.parallel_apply(convert_id, args = ('assetNumber', ), axis = 1)

# %%
# date cols
date_cols = ['reportingPeriodBeginningDate', 'reportingPeriodEndingDate', 'originationDate', 'loanMaturityDate', 'originalFirstPaymentDate', 'interestPaidThroughDate', 'zeroBalanceEffectiveDate', 'mostRecentServicingTransferReceivedDate', 'DemandResolutionDate']

# %%
for col in date_cols:
    print(col)
    data['{}R'.format(col)] = data.parallel_apply(reorder_date, args = (col, ), axis = 1)
# Out:
# reportingPeriodBeginningDate
# reportingPeriodEndingDate
# originationDate
# loanMaturityDate
# originalFirstPaymentDate
# interestPaidThroughDate
# zeroBalanceEffectiveDate
# mostRecentServicingTransferReceivedDate
# DemandResolutionDate

# %%
replacer_cols = ['originalLoanAmount', 'originalLoanTerm', 'originalInterestRatePercentage', 'gracePeriodNumber', 'obligorCreditScore', 'paymentToIncomePercentage', 'reportingPeriodBeginningLoanBalanceAmount', 'nextReportingPeriodPaymentAmountDue', 'reportingPeriodInterestRatePercentage', 'nextInterestRatePercentage', 'servicingFeePercentage', 'servicingFlatFeeAmount', 'otherServicerFeeRetainedByServicer', 'otherAssessedUncollectedServicerFeeAmount', 'scheduledInterestAmount', 'scheduledPrincipalAmount', 'otherPrincipalAdjustmentAmount', 'reportingPeriodActualEndBalanceAmount', 'reportingPeriodScheduledPaymentAmount', 'totalActualAmountPaid', 'actualInterestCollectedAmount', 'actualPrincipalCollectedAmount', 'actualOtherCollectedAmount', 'servicerAdvancedAmount', 'currentDelinquencyStatus', 'repurchaseAmount', 'chargedoffPrincipalAmount', 'recoveredAmount', 'repossessedProceedsAmount']

# %%
data[replacer_cols] = data[replacer_cols].replace('-', np.nan)

# %%
# clean cols
clean_cols = ['currentDelinquencyStatus']
for col in clean_cols:
    data[col] = data[col].str.strip()
    data[col] = data[col].astype(float)

# %%
def replace_val(row, column):
    
    """
    Replace numeric values
    """
    
    init = str(row[column]).strip().replace(';', '')
    if init in ['0', '1', '2', '3', '4', '5', '98', '99']:
        mapped = mapper[column][init]
        return mapped
    else:
        if init[0] in ['0', '1', '2', '3', '4', '5']:
            use = init[0]
        elif init == '-':
            use_keys = list(mapper[column].keys())
            if '98' in use_keys:
                use = '98'
            elif '99' in use_keys:
                use = '99'
        else:
            use = init
        mapped = mapper[column][use]
    return mapped

# %%
for col in m_cols:
    print(col)
    new_col = col + 'M'
    data[new_col] = data.parallel_apply(replace_val, args = (col, ), axis = 1)
# Out:
# interestCalculationTypeCode
# originalInterestRateTypeCode
# paymentTypeCode
# subvented
# vehicleNewUsedCode
# vehicleTypeCode
# vehicleValueSourceCode
# obligorIncomeVerificationLevelCode
# obligorEmploymentVerificationCode
# servicingAdvanceMethodCode
# zeroBalanceCode
# assetSubjectDemandStatusCode
# repurchaseReplacementReasonCode
# modificationTypeCode

# %%
def acct_status(row, b_col, e_col, zero_col, thresh):
    
    """
    Create karus account status
    """
    
    b = float(row[b_col])
    e = float(row[e_col])
    z = str(row[zero_col])
    
    if z in ['Charged-off', 'Repurchased or Replaced']:
        res = z
        return res
    if b < thresh and e < thresh:
        res = 'Prepaid or Matured'
        return res
    if z in ['Unavailable', 'Prepaid or Matured']:
        res = z
        return res

# %%
b_col = 'reportingPeriodBeginningLoanBalanceAmount'
e_col = 'nextReportingPeriodPaymentAmountDue'
z_col = 'zeroBalanceCodeM'
thresh = 50

# %%
data['accountStatus'] = data.parallel_apply(acct_status, args = (b_col, e_col, z_col, thresh, ), axis = 1)

# %%
data['accountStatus'].value_counts()
# Out:
# Unavailable                1458409
# Charged-off                26714
# Prepaid or Matured         26234
# Repurchased or Replaced    37
# Name: accountStatus, dtype: int64

# %%
def get_target(row):
    
    """
    Set target var
    """
    
    init = str(row['accountStatusEvent'])
    remaining = row['remainingTermToMaturityNumberMinPrior']
    
    if init == 'Charged-off':
        res = 'Charged-off'
        return res

    if init == 'Prepaid or Matured' and remaining > 0:
        res = 'Prepaid'
        return res
    
    if init == 'Prepaid or Matured' and remaining < 1:
        res = 'Closed'
        return res
    
    if init == 'nan':
        res = 'Active or other'
        return res

# %%
static['target'] = static.apply(get_target, axis = 1)

# %% [markdown]
# ### Applitcaion

# %%
list(data['ID'].unique())
# Out:
# ['0001694010 - 000010',
#  '0001694010 - 000088',
#  '0001694010 - 000264',
#  '0001694010 - 000338',
#  '0001694010 - 000358',
#  '0001694010 - 000378',
#  '0001694010 - 000382',
#  '0001694010 - 000564',
#  '0001694010 - 000686',
#  '0001694010 - 000974',
#  '0001694010 - 001037',
#  '0001694010 - 001274',
#  '0001694010 - 001378',
#  '0001694010 - 002070',
#  '0001694010 - 002276',
loc_cols = list(set(['originatorName', 'primaryLoanServicerName', 'originationDateR', 'originalLoanAmount', 'originalLoanTerm', 'loanMaturityDateR', 'originalInterestRatePercentage', 'interestCalculationTypeCodeM', 'originalInterestRateTypeCodeM', 'originalInterestOnlyTermNumber', 'originalFirstPaymentDateR', 'underwritingIndicator', 'paymentTypeCodeM', 'vehicleManufacturerName', 'vehicleModelName', 'vehicleNewUsedCodeM', 'vehicleModelYear', 'vehicleTypeCodeM', 'vehicleValueAmount', 'vehicleValueSourceCodeM', 'obligorCreditScoreType', 'obligorIncomeVerificationLevelCodeM', 'obligorEmploymentVerificationCodeM', 'coObligorIndicator', 'paymentToIncomePercentage', 'obligorGeographicLocation', 'assetAddedIndicator', 'reportingPeriodModificationIndicator', 'servicingAdvanceMethodCodeM', 'reportingPeriodBeginningLoanBalanceAmount', 'nextReportingPeriodPaymentAmountDue', 'reportingPeriodInterestRatePercentage', 'nextInterestRatePercentage', 'scheduledInterestAmount', 'otherPrincipalAdjustmentAmount', 'reportingPeriodActualEndBalanceAmount', 'reportingPeriodScheduledPaymentAmount', 'assetSubjectDemandIndicator', 'zeroBalanceEffectiveDateR']))         
min_max_cols = list(set(['reportingPeriodBeginningDateR', 'reportingPeriodEndingDateR', 'remainingTermToMaturityNumber', 'obligorCreditScore', 'reportingPeriodBeginningLoanBalanceAmount', 'nextReportingPeriodPaymentAmountDue']))
max_cols = list(set(['gracePeriodNumber', 'interestPaidThroughDateR', 'mostRecentServicingTransferReceivedDateR', 'chargedoffPrincipalAmount', 'recoveredAmount', 'paymentExtendedNumber', 'repossessedProceedsAmount', 'currentDelinquencyStatus']))
all_vals = list(set(['subventedM', 'assetSubjectDemandIndicator', 'assetSubjectDemandStatusCodeM', 'repurchaserName', 'repurchaseReplacementReasonCodeM', 'modificationTypeCodeM', 'repossessedIndicator', 'zeroBalanceCodeM', 'accountStatus']))
sum_cols = list(set(['servicingFeePercentage', 'servicingFlatFeeAmount', 'otherServicerFeeRetainedByServicer', 'otherAssessedUncollectedServicerFeeAmount', 'totalActualAmountPaid', 'actualInterestCollectedAmount', 'actualPrincipalCollectedAmount', 'actualOtherCollectedAmount', 'servicerAdvancedAmount', 'currentDelinquencyStatus', 'repurchaseAmount', 'chargedoffPrincipalAmount', 'recoveredAmount', 'paymentExtendedNumber', 'repossessedProceedsAmount', 'repossessedProceedsAmount', 'gracePeriodNumber']))
event_cols = list(set(['accountStatus', 'zeroBalanceCodeM', 'chargedoffPrincipalAmount', 'reportingPeriodBeginningDateR', 'reportingPeriodEndingDateR']))

# %%
id_col = 'ID'
_id = '0001694010 - 000264'
status_col = 'accountStatus'
values = ['Charged-off', 'Prepaid or Matured', 'Repurchased or Replaced']

# %%
df = data[data[id_col] == _id].reset_index(drop = True)
df = df.sort_values('reportingPeriodBeginningDateR', ascending = False)

# dict
account_dict = {}
account_dict['id'] = _id
account_dict['records'] = len(df)

# current status of loan
for col in loc_cols:
    account_dict['{}LocCurrent'.format(col)] = df[col].iloc[0]
for col in min_max_cols:
    _min = df[col].min()
    _max = df[col].max()
    account_dict['{}MinCurrent'.format(col)] = _min
    account_dict['{}MaxCurrent'.format(col)] = _max
for col in max_cols:
    account_dict['{}MaxCurrent'.format(col)] = df[col].max()
for col in all_vals:
    vals = list(df[col].unique())
    use_vals = ' | '.join(str(val) for val in vals)
    account_dict['{}ValsCurrent'.format(col)] = use_vals
for col in sum_cols:
    account_dict['{}SumCurrent'.format(col)] = df[col].sum()

# event information
init_vals = list(df[status_col].unique())
inter = list(set(values).intersection(init_vals))
if len(inter) > 0:
    account_dict['eventOccurred'] = 1
    n = df[status_col].where(df[status_col].isin(values)).last_valid_index()
    n_bool = True
    single = df.loc[[n]]
    for col in event_cols:
        account_dict['{}Event'.format(col)] = single[col].iloc[0]

    # prior to event
    init = n+1
    sub = df[init:len(df)]
    sub.reset_index(drop = True, inplace = True)
    account_dict['priorHistory'] = len(sub)
    sub_bool = True
    if len(sub) > 0:
        for col in loc_cols:
            account_dict['{}LocPrior'.format(col)] = sub[col].iloc[0]
        for col in min_max_cols:
            _min = sub[col].min()
            _max = sub[col].max()
            account_dict['{}MinPrior'.format(col)] = _min
            account_dict['{}MaxPrior'.format(col)] = _max
        for col in max_cols:
            account_dict['{}MaxPrior'.format(col)] = sub[col].max()
        for col in all_vals:
            vals = list(sub[col].unique())
            use_vals = ' | '.join(str(val) for val in vals)
            account_dict['{}ValsPrior'.format(col)] = use_vals
        for col in sum_cols:
            account_dict['{}SumPrior'.format(col)] = sub[col].sum()
            
        # random
        len_sub = len(sub)
        s = random.randint(0, len_sub)
        r_sub = sub[s:len_sub].reset_index(drop = True)
        account_dict['randomIndex'] = s
        for col in loc_cols:
            account_dict['{}LocRandom'.format(col)] = r_sub[col].iloc[0]
        for col in min_max_cols:
            _min = r_sub[col].min()
            _max = r_sub[col].max()
            account_dict['{}MinRandon'.format(col)] = _min
            account_dict['{}MaxRandom'.format(col)] = _max
        for col in max_cols:
            account_dict['{}MaxRandom'.format(col)] = r_sub[col].max()
        for col in all_vals:
            vals = list(r_sub[col].unique())
            use_vals = ' | '.join(str(val) for val in vals)
            account_dict['{}ValsRandom'.format(col)] = use_vals
        for col in sum_cols:
            account_dict['{}SumRandom'.format(col)] = r_sub[col].sum()
            
    # if event is first row of sub       
    else:
        for col in loc_cols:
            account_dict['{}LocPrior'.format(col)] = df[col].iloc[0]
        for col in min_max_cols:
            _min = df[col].min()
            _max = df[col].max()
            account_dict['{}MinPrior'.format(col)] = _min
            account_dict['{}MaxPrior'.format(col)] = _max
        for col in max_cols:
            account_dict['{}MaxPrior'.format(col)] = df[col].max()
        for col in all_vals:
            vals = list(df[col].unique())
            use_vals = ' | '.join(str(val) for val in vals)
            account_dict['{}ValsPrior'.format(col)] = use_vals
        for col in sum_cols:
            account_dict['{}SumPrior'.format(col)] = df[col].sum()

# if no event        
else:
    account_dict['eventOccured'] = 0
    account_dict['priorHistory'] = len(df)
    sub_bool = False
    n_bool = False
    for col in event_cols:
        account_dict['{}Event'.format(col)] = np.nan
    for col in loc_cols:
        account_dict['{}LocPrior'.format(col)] = df[col].iloc[0]
    for col in min_max_cols:
        _min = df[col].min()
        _max = df[col].max()
        account_dict['{}MinPrior'.format(col)] = _min
        account_dict['{}MaxPrior'.format(col)] = _max
    for col in max_cols:
        account_dict['{}MaxPrior'.format(col)] = df[col].max()
    for col in all_vals:
        vals = list(df[col].unique())
        use_vals = ' | '.join(str(val) for val in vals)
        account_dict['{}ValsPrior'.format(col)] = use_vals
    for col in sum_cols:
        account_dict['{}SumPrior'.format(col)] = df[col].sum()
    
    # random set to nan
    account_dict['randomIndex'] = np.nan
    for col in loc_cols:
        account_dict['{}LocRandom'.format(col)] = np.nan
    for col in min_max_cols:
        account_dict['{}MinRandon'.format(col)] = np.nan
        account_dict['{}MaxRandom'.format(col)] = np.nan
    for col in max_cols:
        account_dict['{}MaxRandom'.format(col)] = np.nan
    for col in all_vals:
        account_dict['{}ValsRandom'.format(col)] = np.nan
    for col in sum_cols:
        account_dict['{}SumRandom'.format(col)] = np.nan

# %%
account_dict
# Out:
# {'id': '0001694010 - 000264',
#  'records': 47,
#  'originalLoanAmountLocCurrent': 21166.38,
#  'originalLoanTermLocCurrent': 73,
#  'originalInterestOnlyTermNumberLocCurrent': 0,
#  'coObligorIndicatorLocCurrent': True,
#  'reportingPeriodBeginningLoanBalanceAmountLocCurrent': 0.28,
#  'obligorEmploymentVerificationCodeMLocCurrent': 'Stated, not verified',
#  'vehicleModelYearLocCurrent': 2012,
#  'nextReportingPeriodPaymentAmountDueLocCurrent': 0.35,
#  'vehicleManufacturerNameLocCurrent': 'CHEVROLET',
#  'underwritingIndicatorLocCurrent': True,
#  'obligorGeographicLocationLocCurrent': 'NY',
#  'servicingAdvanceMethodCodeMLocCurrent': 'No advancing',
#  'vehicleTypeCodeMLocCurrent': 'Car',
#  'originatorNameLocCurrent': 'GM FINANCIAL',
#  'obligorCreditScoreTypeLocCurrent': 'Credit Bureau Score',
#  'nextInterestRatePercentageLocCurrent': '0.10900000',
#  'reportingPeriodScheduledPaymentAmountLocCurrent': 0.0,
#  'zeroBalanceEffectiveDateRLocCurrent': '',
#  'obligorIncomeVerificationLevelCodeMLocCurrent': 'Stated, not verified',
#  'originalInterestRateTypeCodeMLocCurrent': 'Fixed',
#  'originationDateRLocCurrent': '2012-03',
#  'vehicleModelNameLocCurrent': 'MALIBU',
#  'assetAddedIndicatorLocCurrent': False,
#  'otherPrincipalAdjustmentAmountLocCurrent': 0.0,
#  'loanMaturityDateRLocCurrent': '2018-06',
#  'interestCalculationTypeCodeMLocCurrent': 'Simple',
#  'primaryLoanServicerNameLocCurrent': 'GM FINANCIAL',
#  'reportingPeriodActualEndBalanceAmountLocCurrent': 0.28,
#  'scheduledInterestAmountLocCurrent': 0.0,
#  'originalFirstPaymentDateRLocCurrent': '2012-04',
#  'reportingPeriodInterestRatePercentageLocCurrent': '0.10900000',
#  'paymentToIncomePercentageLocCurrent': 0.0819,
#  'paymentTypeCodeMLocCurrent': 'Monthly',
#  'vehicleValueAmountLocCurrent': 23472.0,
#  'reportingPeriodModificationIndicatorLocCurrent': False,
#  'vehicleNewUsedCodeMLocCurrent': 'New',
#  'originalInterestRatePercentageLocCurrent': 0.109,
#  'assetSubjectDemandIndicatorLocCurrent': False,
#  'vehicleValueSourceCodeMLocCurrent': 'Invoice Price',
#  'remainingTermToMaturityNumberMinCurrent': -29,
#  'remainingTermToMaturityNumberMaxCurrent': 18,
#  'reportingPeriodBeginningLoanBalanceAmountMinCurrent': 0.28,
#  'reportingPeriodBeginningLoanBalanceAmountMaxCurrent': 7382.95,
#  'reportingPeriodBeginningDateRMinCurrent': '2016-12-01',
#  'reportingPeriodBeginningDateRMaxCurrent': '2020-11-01',
#  'obligorCreditScoreMinCurrent': '562',
#  'obligorCreditScoreMaxCurrent': '562',
#  'reportingPeriodEndingDateRMinCurrent': '2016-12-31',
#  'reportingPeriodEndingDateRMaxCurrent': '2020-11-30',
#  'nextReportingPeriodPaymentAmountDueMinCurrent': 0.28,
#  'nextReportingPeriodPaymentAmountDueMaxCurrent': 846.56441863,
#  'paymentExtendedNumberMaxCurrent': 0,
#  'gracePeriodNumberMaxCurrent': 1,
#  'chargedoffPrincipalAmountMaxCurrent': 0.0,
#  'interestPaidThroughDateRMaxCurrent': '2018-08-09',
#  'mostRecentServicingTransferReceivedDateRMaxCurrent': '',
#  'repossessedProceedsAmountMaxCurrent': 0.0,
#  'recoveredAmountMaxCurrent': 0.0,
#  'currentDelinquencyStatusMaxCurrent': 51.0,
#  'assetSubjectDemandStatusCodeMValsCurrent': 'Other',
#  'modificationTypeCodeMValsCurrent': 'Other',
#  'repossessedIndicatorValsCurrent': 'False',
#  'zeroBalanceCodeMValsCurrent': 'Unavailable',
#  'repurchaserNameValsCurrent': '-',
#  'repurchaseReplacementReasonCodeMValsCurrent': 'Other',
#  'accountStatusValsCurrent': 'Prepaid or Matured | Unavailable',
#  'subventedMValsCurrent': 'Yes - Cash Rebate | Yes - Rate Subvention',
#  'assetSubjectDemandIndicatorValsCurrent': 'False',
#  'repurchaseAmountSumCurrent': 0.0,
#  'paymentExtendedNumberSumCurrent': 0,
#  'servicerAdvancedAmountSumCurrent': 0.0,
#  'chargedoffPrincipalAmountSumCurrent': 0.0,
#  'otherAssessedUncollectedServicerFeeAmountSumCurrent': 829.8499999999999,
#  'actualOtherCollectedAmountSumCurrent': 0.0,
#  'gracePeriodNumberSumCurrent': 47,
#  'otherServicerFeeRetainedByServicerSumCurrent': 0.0,
#  'repossessedProceedsAmountSumCurrent': 0.0,
#  'actualInterestCollectedAmountSumCurrent': 681.6300000000001,
#  'actualPrincipalCollectedAmountSumCurrent': 7045.9800000000005,
#  'servicingFlatFeeAmountSumCurrent': 0.0,
#  'recoveredAmountSumCurrent': 0.0,
#  'servicingFeePercentageSumCurrent': 1.0574999999999997,
#  'currentDelinquencyStatusSumCurrent': 89.0,
#  'totalActualAmountPaidSumCurrent': 7727.610000000001,
#  'eventOccurred': 1,
#  'chargedoffPrincipalAmountEvent': 0.0,
#  'reportingPeriodBeginningDateREvent': '2018-09-01',
#  'zeroBalanceCodeMEvent': 'Unavailable',
#  'accountStatusEvent': 'Prepaid or Matured',
#  'reportingPeriodEndingDateREvent': '2018-09-30',
#  'priorHistory': 20,
#  'originalLoanAmountLocPrior': 21166.38,
#  'originalLoanTermLocPrior': 73,
#  'originalInterestOnlyTermNumberLocPrior': 0,
#  'coObligorIndicatorLocPrior': True,
#  'reportingPeriodBeginningLoanBalanceAmountLocPrior': 465.57,
#  'obligorEmploymentVerificationCodeMLocPrior': 'Stated, not verified',
#  'vehicleModelYearLocPrior': 2012,
#  'nextReportingPeriodPaymentAmountDueLocPrior': 0.28,
#  'vehicleManufacturerNameLocPrior': 'CHEVROLET',
#  'underwritingIndicatorLocPrior': True,
#  'obligorGeographicLocationLocPrior': 'NY',
#  'servicingAdvanceMethodCodeMLocPrior': 'No advancing',
#  'vehicleTypeCodeMLocPrior': 'Car',
#  'originatorNameLocPrior': 'GM FINANCIAL',
#  'obligorCreditScoreTypeLocPrior': 'Credit Bureau Score',
#  'nextInterestRatePercentageLocPrior': '0.10900000',
#  'reportingPeriodScheduledPaymentAmountLocPrior': 0.0,
#  'zeroBalanceEffectiveDateRLocPrior': '',
#  'obligorIncomeVerificationLevelCodeMLocPrior': 'Stated, not verified',
#  'originalInterestRateTypeCodeMLocPrior': 'Fixed',
#  'originationDateRLocPrior': '2012-03',
#  'vehicleModelNameLocPrior': 'MALIBU',
#  'assetAddedIndicatorLocPrior': False,
#  'otherPrincipalAdjustmentAmountLocPrior': 0.0,
#  'loanMaturityDateRLocPrior': '2018-06',
#  'interestCalculationTypeCodeMLocPrior': 'Simple',
#  'primaryLoanServicerNameLocPrior': 'GM FINANCIAL',
#  'reportingPeriodActualEndBalanceAmountLocPrior': 0.28,
#  'scheduledInterestAmountLocPrior': 0.0,
#  'originalFirstPaymentDateRLocPrior': '2012-04',
#  'reportingPeriodInterestRatePercentageLocPrior': '0.10900000',
#  'paymentToIncomePercentageLocPrior': 0.0819,
#  'paymentTypeCodeMLocPrior': 'Monthly',
#  'vehicleValueAmountLocPrior': 23472.0,
#  'reportingPeriodModificationIndicatorLocPrior': False,
#  'vehicleNewUsedCodeMLocPrior': 'New',
#  'originalInterestRatePercentageLocPrior': 0.109,
#  'assetSubjectDemandIndicatorLocPrior': False,
#  'vehicleValueSourceCodeMLocPrior': 'Invoice Price',
#  'remainingTermToMaturityNumberMinPrior': -2,
#  'remainingTermToMaturityNumberMaxPrior': 18,
#  'reportingPeriodBeginningLoanBalanceAmountMinPrior': 465.57,
#  'reportingPeriodBeginningLoanBalanceAmountMaxPrior': 7382.95,
#  'reportingPeriodBeginningDateRMinPrior': '2016-12-01',
#  'reportingPeriodBeginningDateRMaxPrior': '2018-08-01',
#  'obligorCreditScoreMinPrior': '562',
#  'obligorCreditScoreMaxPrior': '562',
#  'reportingPeriodEndingDateRMinPrior': '2016-12-31',
#  'reportingPeriodEndingDateRMaxPrior': '2018-08-31',
#  'nextReportingPeriodPaymentAmountDueMinPrior': 0.28,
#  'nextReportingPeriodPaymentAmountDueMaxPrior': 846.56441863,
#  'paymentExtendedNumberMaxPrior': 0,
#  'gracePeriodNumberMaxPrior': 1,
#  'chargedoffPrincipalAmountMaxPrior': 0.0,
#  'interestPaidThroughDateRMaxPrior': '2018-08-09',
#  'mostRecentServicingTransferReceivedDateRMaxPrior': '',
#  'repossessedProceedsAmountMaxPrior': 0.0,
#  'recoveredAmountMaxPrior': 0.0,
#  'currentDelinquencyStatusMaxPrior': 51.0,
#  'assetSubjectDemandStatusCodeMValsPrior': 'Other',
#  'modificationTypeCodeMValsPrior': 'Other',
#  'repossessedIndicatorValsPrior': 'False',
#  'zeroBalanceCodeMValsPrior': 'Unavailable',
#  'repurchaserNameValsPrior': '-',
#  'repurchaseReplacementReasonCodeMValsPrior': 'Other',
#  'accountStatusValsPrior': 'Unavailable',
#  'subventedMValsPrior': 'Yes - Cash Rebate | Yes - Rate Subvention',
#  'assetSubjectDemandIndicatorValsPrior': 'False',
#  'repurchaseAmountSumPrior': 0.0,
#  'paymentExtendedNumberSumPrior': 0,
#  'servicerAdvancedAmountSumPrior': 0.0,
#  'chargedoffPrincipalAmountSumPrior': 0.0,
#  'otherAssessedUncollectedServicerFeeAmountSumPrior': 206.69,
#  'actualOtherCollectedAmountSumPrior': 0.0,
#  'gracePeriodNumberSumPrior': 20,
#  'otherServicerFeeRetainedByServicerSumPrior': 0.0,
#  'repossessedProceedsAmountSumPrior': 0.0,
#  'actualInterestCollectedAmountSumPrior': 681.63,
#  'actualPrincipalCollectedAmountSumPrior': 7045.9800000000005,
#  'servicingFlatFeeAmountSumPrior': 0.0,
#  'recoveredAmountSumPrior': 0.0,
#  'servicingFeePercentageSumPrior': 0.45000000000000007,
#  'currentDelinquencyStatusSumPrior': 89.0,
#  'totalActualAmountPaidSumPrior': 7727.610000000001,
#  'randomIndex': 16,
#  'originalLoanAmountLocRandom': 21166.38,
#  'originalLoanTermLocRandom': 73,
#  'originalInterestOnlyTermNumberLocRandom': 0,
#  'coObligorIndicatorLocRandom': True,
#  'reportingPeriodBeginningLoanBalanceAmountLocRandom': 6029.63,
#  'obligorEmploymentVerificationCodeMLocRandom': 'Stated, not verified',
#  'vehicleModelYearLocRandom': 2012,
#  'nextReportingPeriodPaymentAmountDueLocRandom': 401.8,
#  'vehicleManufacturerNameLocRandom': 'CHEVROLET',
#  'underwritingIndicatorLocRandom': True,
#  'obligorGeographicLocationLocRandom': 'NY',
#  'servicingAdvanceMethodCodeMLocRandom': 'No advancing',
#  'vehicleTypeCodeMLocRandom': 'Car',
#  'originatorNameLocRandom': 'GM FINANCIAL',
#  'obligorCreditScoreTypeLocRandom': 'Credit Bureau Score',
#  'nextInterestRatePercentageLocRandom': '0.10900000',
#  'reportingPeriodScheduledPaymentAmountLocRandom': 401.8,
#  'zeroBalanceEffectiveDateRLocRandom': '',
#  'obligorIncomeVerificationLevelCodeMLocRandom': 'Stated, not verified',
#  'originalInterestRateTypeCodeMLocRandom': 'Fixed',
#  'originationDateRLocRandom': '2012-03',
#  'vehicleModelNameLocRandom': 'MALIBU',
#  'assetAddedIndicatorLocRandom': False,
#  'otherPrincipalAdjustmentAmountLocRandom': 0.0,
#  'loanMaturityDateRLocRandom': '2018-06',
#  'interestCalculationTypeCodeMLocRandom': 'Simple',
#  'primaryLoanServicerNameLocRandom': 'GM FINANCIAL',
#  'reportingPeriodActualEndBalanceAmountLocRandom': 5683.45,
#  'scheduledInterestAmountLocRandom': 41.31630507,
#  'originalFirstPaymentDateRLocRandom': '2012-04',
#  'reportingPeriodInterestRatePercentageLocRandom': '0.10900000',
#  'paymentToIncomePercentageLocRandom': 0.0819,
#  'paymentTypeCodeMLocRandom': 'Monthly',
#  'vehicleValueAmountLocRandom': 23472.0,
#  'reportingPeriodModificationIndicatorLocRandom': False,
#  'vehicleNewUsedCodeMLocRandom': 'New',
#  'originalInterestRatePercentageLocRandom': 0.109,
#  'assetSubjectDemandIndicatorLocRandom': False,
#  'vehicleValueSourceCodeMLocRandom': 'Invoice Price',
#  'remainingTermToMaturityNumberMinRandon': 14,
#  'remainingTermToMaturityNumberMaxRandom': 18,
#  'reportingPeriodBeginningLoanBalanceAmountMinRandon': 6029.63,
#  'reportingPeriodBeginningLoanBalanceAmountMaxRandom': 7382.95,
#  'reportingPeriodBeginningDateRMinRandon': '2016-12-01',
#  'reportingPeriodBeginningDateRMaxRandom': '2017-04-01',
#  'obligorCreditScoreMinRandon': '562',
#  'obligorCreditScoreMaxRandom': '562',
#  'reportingPeriodEndingDateRMinRandon': '2016-12-31',
#  'reportingPeriodEndingDateRMaxRandom': '2017-04-30',
#  'nextReportingPeriodPaymentAmountDueMinRandon': 401.8,
#  'nextReportingPeriodPaymentAmountDueMaxRandom': 401.8,
#  'paymentExtendedNumberMaxRandom': 0,
#  'gracePeriodNumberMaxRandom': 1,
#  'chargedoffPrincipalAmountMaxRandom': 0.0,
#  'interestPaidThroughDateRMaxRandom': '2017-04-14',
#  'mostRecentServicingTransferReceivedDateRMaxRandom': '',
#  'repossessedProceedsAmountMaxRandom': 0.0,
#  'recoveredAmountMaxRandom': 0.0,
#  'currentDelinquencyStatusMaxRandom': 0.0,
#  'assetSubjectDemandStatusCodeMValsRandom': 'Other',
#  'modificationTypeCodeMValsRandom': 'Other',
#  'repossessedIndicatorValsRandom': 'False',
#  'zeroBalanceCodeMValsRandom': 'Unavailable',
#  'repurchaserNameValsRandom': '-',
#  'repurchaseReplacementReasonCodeMValsRandom': 'Other',
#  'accountStatusValsRandom': 'Unavailable',
#  'subventedMValsRandom': 'Yes - Cash Rebate | Yes - Rate Subvention',
#  'assetSubjectDemandIndicatorValsRandom': 'False',
#  'repurchaseAmountSumRandom': 0.0,
#  'paymentExtendedNumberSumRandom': 0,
#  'servicerAdvancedAmountSumRandom': 0.0,
#  'chargedoffPrincipalAmountSumRandom': 0.0,
#  'otherAssessedUncollectedServicerFeeAmountSumRandom': 0.0,
#  'actualOtherCollectedAmountSumRandom': 0.0,
#  'gracePeriodNumberSumRandom': 4,
#  'otherServicerFeeRetainedByServicerSumRandom': 0.0,
#  'repossessedProceedsAmountSumRandom': 0.0,
#  'actualInterestCollectedAmountSumRandom': 244.79000000000002,
#  'actualPrincipalCollectedAmountSumRandom': 1362.81,
#  'servicingFlatFeeAmountSumRandom': 0.0,
#  'recoveredAmountSumRandom': 0.0,
#  'servicingFeePercentageSumRandom': 0.09,
#  'currentDelinquencyStatusSumRandom': 0.0,
#  'totalActualAmountPaidSumRandom': 1607.6}

# %%
len(account_dict)
# Out:
# 262

# %%
res_dict = {}

# %%
for col in loc_cols:
    
    cor = col + 'LocCurrent'
    val = account_dict[cor]
    comp = df[col].iloc[0]
    
    if str(val) == str(comp):
        res = 'Match'
    else:
        res = 'No match'
    
    if res == 'No match':
        print('NO MATCH!!!!!!!')
    
    res_dict[cor] = {'res': res, 'val': val}

# %%
for col in loc_cols:
    
    if sub_bool == True:
        use_df = sub
    elif sub_bool == False:
        use_df = df
    
    cor = col + 'LocPrior'
    val = account_dict[cor]
    comp = use_df[col].iloc[0]
    
    if str(val) == str(comp):
        res = 'Match'
    else:
        res = 'No match'
        
    if res == 'No match':
        print('NO MATCH!!!!!!!')
    
    res_dict[cor] = {'res': res, 'val': val}

# %%
for col in event_cols:
    
    cor = col + 'Event'
    val = account_dict[cor]
    
    if n_bool == True:
        comp = single[col].iloc[0]
    else:
        comp = str(np.nan)
    
    if str(val) == str(comp):
        res = 'Match'
    else:
        res = 'No match'
    
    if res == 'No match':
        print('NO MATCH!!!!!!!')
    
    res_dict[cor] = {'res': res, 'val': val}

# %%
for col in loc_cols:
    
    if sub_bool == True:
        use_df = r_sub
    elif sub_bool == False:
        use_df = df
    
    cor = col + 'LocRandom'
    val = account_dict[cor]
    comp = use_df[col].iloc[0]
    
    if str(val) == str(comp):
        res = 'Match'
    else:
        res = 'No match'
        
    if res == 'No match':
        print('NO MATCH!!!!!!!')
    
    res_dict[cor] = {'res': res, 'val': val}

# %%
res_dict
# Out:
# {'originalLoanAmountLocCurrent': {'res': 'Match', 'val': 21166.38},
#  'originalLoanTermLocCurrent': {'res': 'Match', 'val': 73},
#  'originalInterestOnlyTermNumberLocCurrent': {'res': 'Match', 'val': 0},
#  'coObligorIndicatorLocCurrent': {'res': 'Match', 'val': True},
#  'reportingPeriodBeginningLoanBalanceAmountLocCurrent': {'res': 'Match',
#   'val': 0.28},
#  'obligorEmploymentVerificationCodeMLocCurrent': {'res': 'Match',
#   'val': 'Stated, not verified'},
#  'vehicleModelYearLocCurrent': {'res': 'Match', 'val': 2012},
#  'nextReportingPeriodPaymentAmountDueLocCurrent': {'res': 'Match',
#   'val': 0.35},
#  'vehicleManufacturerNameLocCurrent': {'res': 'Match', 'val': 'CHEVROLET'},
#  'underwritingIndicatorLocCurrent': {'res': 'Match', 'val': True},
#  'obligorGeographicLocationLocCurrent': {'res': 'Match', 'val': 'NY'},
#  'servicingAdvanceMethodCodeMLocCurrent': {'res': 'Match',
#   'val': 'No advancing'},
#  'vehicleTypeCodeMLocCurrent': {'res': 'Match', 'val': 'Car'},
#  'originatorNameLocCurrent': {'res': 'Match', 'val': 'GM FINANCIAL'},
#  'obligorCreditScoreTypeLocCurrent': {'res': 'Match',
#   'val': 'Credit Bureau Score'},
#  'nextInterestRatePercentageLocCurrent': {'res': 'Match', 'val': '0.10900000'},
#  'reportingPeriodScheduledPaymentAmountLocCurrent': {'res': 'Match',
#   'val': 0.0},
#  'zeroBalanceEffectiveDateRLocCurrent': {'res': 'Match', 'val': ''},
#  'obligorIncomeVerificationLevelCodeMLocCurrent': {'res': 'Match',
#   'val': 'Stated, not verified'},
#  'originalInterestRateTypeCodeMLocCurrent': {'res': 'Match', 'val': 'Fixed'},
#  'originationDateRLocCurrent': {'res': 'Match', 'val': '2012-03'},
#  'vehicleModelNameLocCurrent': {'res': 'Match', 'val': 'MALIBU'},
#  'assetAddedIndicatorLocCurrent': {'res': 'Match', 'val': False},
#  'otherPrincipalAdjustmentAmountLocCurrent': {'res': 'Match', 'val': 0.0},
#  'loanMaturityDateRLocCurrent': {'res': 'Match', 'val': '2018-06'},
#  'interestCalculationTypeCodeMLocCurrent': {'res': 'Match', 'val': 'Simple'},
#  'primaryLoanServicerNameLocCurrent': {'res': 'Match', 'val': 'GM FINANCIAL'},
#  'reportingPeriodActualEndBalanceAmountLocCurrent': {'res': 'Match',
#   'val': 0.28},
#  'scheduledInterestAmountLocCurrent': {'res': 'Match', 'val': 0.0},
#  'originalFirstPaymentDateRLocCurrent': {'res': 'Match', 'val': '2012-04'},
#  'reportingPeriodInterestRatePercentageLocCurrent': {'res': 'Match',
#   'val': '0.10900000'},
#  'paymentToIncomePercentageLocCurrent': {'res': 'Match', 'val': 0.0819},
#  'paymentTypeCodeMLocCurrent': {'res': 'Match', 'val': 'Monthly'},
#  'vehicleValueAmountLocCurrent': {'res': 'Match', 'val': 23472.0},
#  'reportingPeriodModificationIndicatorLocCurrent': {'res': 'Match',
#   'val': False},
#  'vehicleNewUsedCodeMLocCurrent': {'res': 'Match', 'val': 'New'},
#  'originalInterestRatePercentageLocCurrent': {'res': 'Match', 'val': 0.109},
#  'assetSubjectDemandIndicatorLocCurrent': {'res': 'Match', 'val': False},
#  'vehicleValueSourceCodeMLocCurrent': {'res': 'Match', 'val': 'Invoice Price'},
#  'originalLoanAmountLocPrior': {'res': 'Match', 'val': 21166.38},
#  'originalLoanTermLocPrior': {'res': 'Match', 'val': 73},
#  'originalInterestOnlyTermNumberLocPrior': {'res': 'Match', 'val': 0},
#  'coObligorIndicatorLocPrior': {'res': 'Match', 'val': True},
#  'reportingPeriodBeginningLoanBalanceAmountLocPrior': {'res': 'Match',
#   'val': 465.57},
#  'obligorEmploymentVerificationCodeMLocPrior': {'res': 'Match',
#   'val': 'Stated, not verified'},
#  'vehicleModelYearLocPrior': {'res': 'Match', 'val': 2012},
#  'nextReportingPeriodPaymentAmountDueLocPrior': {'res': 'Match', 'val': 0.28},
#  'vehicleManufacturerNameLocPrior': {'res': 'Match', 'val': 'CHEVROLET'},
#  'underwritingIndicatorLocPrior': {'res': 'Match', 'val': True},
#  'obligorGeographicLocationLocPrior': {'res': 'Match', 'val': 'NY'},
#  'servicingAdvanceMethodCodeMLocPrior': {'res': 'Match',
#   'val': 'No advancing'},
#  'vehicleTypeCodeMLocPrior': {'res': 'Match', 'val': 'Car'},
#  'originatorNameLocPrior': {'res': 'Match', 'val': 'GM FINANCIAL'},
#  'obligorCreditScoreTypeLocPrior': {'res': 'Match',
#   'val': 'Credit Bureau Score'},
#  'nextInterestRatePercentageLocPrior': {'res': 'Match', 'val': '0.10900000'},
#  'reportingPeriodScheduledPaymentAmountLocPrior': {'res': 'Match', 'val': 0.0},
#  'zeroBalanceEffectiveDateRLocPrior': {'res': 'Match', 'val': ''},
#  'obligorIncomeVerificationLevelCodeMLocPrior': {'res': 'Match',
#   'val': 'Stated, not verified'},
#  'originalInterestRateTypeCodeMLocPrior': {'res': 'Match', 'val': 'Fixed'},
#  'originationDateRLocPrior': {'res': 'Match', 'val': '2012-03'},
#  'vehicleModelNameLocPrior': {'res': 'Match', 'val': 'MALIBU'},
#  'assetAddedIndicatorLocPrior': {'res': 'Match', 'val': False},
#  'otherPrincipalAdjustmentAmountLocPrior': {'res': 'Match', 'val': 0.0},
#  'loanMaturityDateRLocPrior': {'res': 'Match', 'val': '2018-06'},
#  'interestCalculationTypeCodeMLocPrior': {'res': 'Match', 'val': 'Simple'},
#  'primaryLoanServicerNameLocPrior': {'res': 'Match', 'val': 'GM FINANCIAL'},
#  'reportingPeriodActualEndBalanceAmountLocPrior': {'res': 'Match',
#   'val': 0.28},
#  'scheduledInterestAmountLocPrior': {'res': 'Match', 'val': 0.0},
#  'originalFirstPaymentDateRLocPrior': {'res': 'Match', 'val': '2012-04'},
#  'reportingPeriodInterestRatePercentageLocPrior': {'res': 'Match',
#   'val': '0.10900000'},
#  'paymentToIncomePercentageLocPrior': {'res': 'Match', 'val': 0.0819},
#  'paymentTypeCodeMLocPrior': {'res': 'Match', 'val': 'Monthly'},
#  'vehicleValueAmountLocPrior': {'res': 'Match', 'val': 23472.0},
#  'reportingPeriodModificationIndicatorLocPrior': {'res': 'Match',
#   'val': False},
#  'vehicleNewUsedCodeMLocPrior': {'res': 'Match', 'val': 'New'},
#  'originalInterestRatePercentageLocPrior': {'res': 'Match', 'val': 0.109},
#  'assetSubjectDemandIndicatorLocPrior': {'res': 'Match', 'val': False},
#  'vehicleValueSourceCodeMLocPrior': {'res': 'Match', 'val': 'Invoice Price'},
#  'chargedoffPrincipalAmountEvent': {'res': 'Match', 'val': 0.0},
#  'reportingPeriodBeginningDateREvent': {'res': 'Match', 'val': '2018-09-01'},
#  'zeroBalanceCodeMEvent': {'res': 'Match', 'val': 'Unavailable'},
#  'accountStatusEvent': {'res': 'Match', 'val': 'Prepaid or Matured'},
#  'reportingPeriodEndingDateREvent': {'res': 'Match', 'val': '2018-09-30'},
#  'originalLoanAmountLocRandom': {'res': 'Match', 'val': 21166.38},
#  'originalLoanTermLocRandom': {'res': 'Match', 'val': 73},
#  'originalInterestOnlyTermNumberLocRandom': {'res': 'Match', 'val': 0},
#  'coObligorIndicatorLocRandom': {'res': 'Match', 'val': True},
#  'reportingPeriodBeginningLoanBalanceAmountLocRandom': {'res': 'Match',
#   'val': 6029.63},
#  'obligorEmploymentVerificationCodeMLocRandom': {'res': 'Match',
#   'val': 'Stated, not verified'},
#  'vehicleModelYearLocRandom': {'res': 'Match', 'val': 2012},
#  'nextReportingPeriodPaymentAmountDueLocRandom': {'res': 'Match',
#   'val': 401.8},
#  'vehicleManufacturerNameLocRandom': {'res': 'Match', 'val': 'CHEVROLET'},
#  'underwritingIndicatorLocRandom': {'res': 'Match', 'val': True},
#  'obligorGeographicLocationLocRandom': {'res': 'Match', 'val': 'NY'},
#  'servicingAdvanceMethodCodeMLocRandom': {'res': 'Match',
#   'val': 'No advancing'},
#  'vehicleTypeCodeMLocRandom': {'res': 'Match', 'val': 'Car'},
#  'originatorNameLocRandom': {'res': 'Match', 'val': 'GM FINANCIAL'},
#  'obligorCreditScoreTypeLocRandom': {'res': 'Match',
#   'val': 'Credit Bureau Score'},
#  'nextInterestRatePercentageLocRandom': {'res': 'Match', 'val': '0.10900000'},
#  'reportingPeriodScheduledPaymentAmountLocRandom': {'res': 'Match',
#   'val': 401.8},
#  'zeroBalanceEffectiveDateRLocRandom': {'res': 'Match', 'val': ''},
#  'obligorIncomeVerificationLevelCodeMLocRandom': {'res': 'Match',
#   'val': 'Stated, not verified'},
#  'originalInterestRateTypeCodeMLocRandom': {'res': 'Match', 'val': 'Fixed'},
#  'originationDateRLocRandom': {'res': 'Match', 'val': '2012-03'},
#  'vehicleModelNameLocRandom': {'res': 'Match', 'val': 'MALIBU'},
#  'assetAddedIndicatorLocRandom': {'res': 'Match', 'val': False},
#  'otherPrincipalAdjustmentAmountLocRandom': {'res': 'Match', 'val': 0.0},
#  'loanMaturityDateRLocRandom': {'res': 'Match', 'val': '2018-06'},
#  'interestCalculationTypeCodeMLocRandom': {'res': 'Match', 'val': 'Simple'},
#  'primaryLoanServicerNameLocRandom': {'res': 'Match', 'val': 'GM FINANCIAL'},
#  'reportingPeriodActualEndBalanceAmountLocRandom': {'res': 'Match',
#   'val': 5683.45},
#  'scheduledInterestAmountLocRandom': {'res': 'Match', 'val': 41.31630507},
#  'originalFirstPaymentDateRLocRandom': {'res': 'Match', 'val': '2012-04'},
#  'reportingPeriodInterestRatePercentageLocRandom': {'res': 'Match',
#   'val': '0.10900000'},
#  'paymentToIncomePercentageLocRandom': {'res': 'Match', 'val': 0.0819},
#  'paymentTypeCodeMLocRandom': {'res': 'Match', 'val': 'Monthly'},
#  'vehicleValueAmountLocRandom': {'res': 'Match', 'val': 23472.0},
#  'reportingPeriodModificationIndicatorLocRandom': {'res': 'Match',
#   'val': False},
#  'vehicleNewUsedCodeMLocRandom': {'res': 'Match', 'val': 'New'},
#  'originalInterestRatePercentageLocRandom': {'res': 'Match', 'val': 0.109},
#  'assetSubjectDemandIndicatorLocRandom': {'res': 'Match', 'val': False},
#  'vehicleValueSourceCodeMLocRandom': {'res': 'Match', 'val': 'Invoice Price'}}
